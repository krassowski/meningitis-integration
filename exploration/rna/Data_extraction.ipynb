# %%
from helpers.utilities import *
# %run helpers/notebook_setup.ipynb

# %%
from numpy import nan

# %%
definite_tbm_rna_path = 'data/raw/RNA-Seq/DefiniteTBM_CM_VM/DefTBM_CM_VM.xlsx'
all_samples_path = 'data/raw/RNA-Seq/AllSamples/NormalisedCounts_AllSamples_ConditionFiltered.txt'
metadata_path = 'data/raw/RNA-Seq/AllSamples/ColData.txt'

# outputs
tbm_subset_clean_path = 'data/clean/rna/definite_tbm_against_all.csv'
duplicates_path = 'data/other/duplicates_rna_definite_tbm_subset.csv'

definite_tbm_cm_deg_path = 'data/preliminary_analyses/deg/definite_tbm-cm.csv'
definite_tbm_vm_deg_path = 'data/preliminary_analyses/deg/definite_tbm-vm.csv'
cm_vm_deg_path = 'data/preliminary_analyses/deg/cm-vm.csv'

all_samples_clean_path = 'data/clean/rna/all_samples.csv'
all_samples_duplicates_path = 'data/other/duplicates_rna_all_samples.csv'

# %% [markdown]
# ## Definite TBM subset

# %%
definite_tbm_rna = read_excel(definite_tbm_rna_path, sheet_name=None)

# %%
list(definite_tbm_rna.keys())
# Out:
# ['DEG_P75_TBM_CM', 'DEG_P75_TBM_VM', 'DEG_P75_CM_VM']

# %% [markdown]
# I assume that there are two distinct datasets in the spreedsheets: differentially expressed genes (DEGs) and the actual expression values.

# %% [markdown]
# ### Definite TBM vs viral (DEG_P75_TBM_VM)

# %% [markdown]
# Side note to a reader coming from R: NA (not available/missing value) are represented by NaN (not a number) in Python/pandas, thus you can see NaN where you might expect NA. In some cases None is used to represent NA, though it has a negative impact on data storage efficiency / performance.

# %%
tbm_vm = definite_tbm_rna['DEG_P75_TBM_VM']
tbm_vm.head()
# Out:
#         Ensembl_ID   Feature  \
# 0  ENSG00000000003    TSPAN6
# 1  ENSG00000000419      DPM1
# 2  ENSG00000000457     SCYL3
# 3  ENSG00000000460  C1orf112
# 4  ENSG00000000938       FGR
#
#                                          Description    baseMean  \
# 0                                     tetraspanin 6    14.919135
# 1  dolichyl-phosphate mannosyltransferase subunit...   32.962551
# 2                          SCY1 like pseudokinase 3   120.711337
# 3               chromosome 1 open reading frame 112    28.231420
# 4    FGR proto-oncogene, Src family tyrosine kinase   664.920461
#
#    log2FoldChange  ...      154.VM      156.VM      165.VM      255.VM  \
# 0        1.499861  ...   12.062173    4.743492    2.080339   15.790950
# 1       -0.188709  ...   43.423823   27.145923   15.602543   45.267391
# 2        0.633077  ...  107.353340   84.067823   79.052885   77.902022
# 3       -0.095839  ...   32.567867   45.133619   30.164917   12.632760
# 4        0.735533  ...   85.641429  292.687526  104.016955  326.346310
#
#        205.VM
# 0    4.808728
# 1   32.859642
# 2   88.160015
# 3   36.065461
# 4  164.298209
#
# [5 rows x 47 columns]

# %%
tbm_vm.tail()
# Out:
#             Ensembl_ID     Feature  \
# 21483  ENSG00000284512  AC092718.8
# 21484  ENSG00000284513  AC006063.2
# 21485  ENSG00000284523  AC004834.1
# 21486  ENSG00000284526  AC015802.6
# 21487  ENSG00000284543   LINC01226
#
#                                         Description   baseMean  \
# 21483                                             0  15.697566
# 21484                                             0  13.256127
# 21485                                             0  27.773974
# 21486                                             0  54.314726
# 21487  long intergenic non-protein coding RNA 1226   76.657661
#
#        log2FoldChange  ...     154.VM     156.VM      165.VM      255.VM  \
# 21483       -0.284500  ...  10.855956  12.398830   20.803391   20.001871
# 21484        0.088160  ...   9.649738   7.984095   20.803391   24.212791
# 21485        0.674403  ...  21.711911  21.604021   23.923900   33.687361
# 21486        0.686323  ...  56.692213  27.897367   52.008477   63.163802
# 21487        0.307070  ...  54.279779  45.697202  119.619498  100.009353
#
#           205.VM
# 21483   9.617456
# 21484  16.029094
# 21485  18.433458
# 21486  33.661097
# 21487  42.477098
#
# [5 rows x 47 columns]

# %% [markdown]
# Zeros in the description are assumed to indicate missing values:

# %%
tbm_vm['Description'] = tbm_vm['Description'].replace('0', nan)

# %% [markdown]
# There are 47 columns:

# %%
tbm_vm.columns
# Out:
# Index(['Ensembl_ID', 'Feature', 'Description', 'baseMean', 'log2FoldChange',
#        'lfcSE', 'stat', 'pvalue', 'padj', 'Feature.1', '001.TMD', '017.TMD',
#        '083.TMD', '101.TMD', '136.TMD', '149.TMD', '151.TMD', '168.TMD',
#        '170.TMD', '241.TMD', '242.TMD', '185.TMD', '006.CM', '016.CM',
#        '018.CM', '058.CM', '103.CM', '120.CM', '123.CM', '145.CM', '220.CM',
#        '224.CM', '240.CM', '244.CM', '256.CM', '206.CM', '174.CM', '078.CM',
#        '261.CM', '048.VM', '089.VM', '095.VM', '154.VM', '156.VM', '165.VM',
#        '255.VM', '205.VM'],
#       dtype='object')

# %% [markdown]
# which include data for both definite TB, VM (viral) and CM (cryptococcal).

# %% [markdown]
# `Feature.1` is just the same as `Feature`:

# %%
(tbm_vm['Feature'] == tbm_vm['Feature.1']).all()
# Out:
# True

# %% [markdown]
# I will drop the redundant one:

# %%
tbm_vm = tbm_vm.drop('Feature.1', axis='columns')

# %% [markdown]
# `Feature` appears to represent Ensembl Gene Name (AC116366.3 is a hint - this is an EBI, versioned format)

# %%
tbm_vm = tbm_vm.rename(columns={'Feature': 'ensembl_gene_name'})

# %% [markdown]
# Standardize index column names:

# %%
from helpers.data_frame import to_lowercase

rna_raw_index = ['Ensembl_ID', 'ensembl_gene_name', 'Description']
tbm_vm.columns = to_lowercase(tbm_vm.columns, limit_to=rna_raw_index)
rna_index = to_lowercase(rna_raw_index)

# %% [markdown]
# and separate the datasets to keep those in a format closer to second normal form (2NF):

# %%
deg_columns = ['baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj']
patient_columns = list(tbm_vm.columns.difference(deg_columns + rna_index))

tbm_vm_deg = tbm_vm[rna_index + deg_columns].set_index(rna_index)
tbm_vm_data = tbm_vm[rna_index + patient_columns].set_index(rna_index)

# %% [markdown]
# #### Data

# %%
tbm_vm_data.head()
# Out:
#                                                                                          001.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        11.335838
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...    0.000000
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                            124.694213
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                  45.343350
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      498.776851
#
#                                                                                           006.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                         7.111529
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...   28.446116
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                            132.748542
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                   0.000000
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      668.483729
#
#                                                                                           016.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        37.483544
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...    0.000000
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                             91.366139
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                  49.197152
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      693.445565
#
#                                                                                           017.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                         25.116886
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...    73.341307
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                             125.584429
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                   15.070131
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      2189.187769
#
#                                                                                            018.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                          0.000000
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...    33.845488
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                             105.162765
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                   19.340279
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      1375.577318
#
#                                                                                       ...  \
# ensembl_id      ensembl_gene_name description                                         ...
# ENSG00000000003 TSPAN6            tetraspanin 6                                       ...
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...  ...
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                            ...
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                 ...
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      ...
#
#                                                                                          242.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        44.547274
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...   46.738124
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                             64.995203
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                   9.493681
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      749.270547
#
#                                                                                           244.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        11.084592
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...    0.000000
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                            151.225503
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                   0.000000
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      235.151698
#
#                                                                                           255.VM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        15.790950
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...   45.267391
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                             77.902022
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                  12.632760
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      326.346310
#
#                                                                                           256.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        10.457265
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...   16.034472
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                             92.721079
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                  25.097435
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      123.395721
#
#                                                                                           261.CM
# ensembl_id      ensembl_gene_name description
# ENSG00000000003 TSPAN6            tetraspanin 6                                        20.323391
# ENSG00000000419 DPM1              dolichyl-phosphate mannosyltransferase subunit ...   39.020910
# ENSG00000000457 SCYL3             SCY1 like pseudokinase 3                            123.566216
# ENSG00000000460 C1orf112          chromosome 1 open reading frame 112                  30.078618
# ENSG00000000938 FGR               FGR proto-oncogene, Src family tyrosine kinase      263.391144
#
# [5 rows x 37 columns]

# %%
tbm_vm_data.tail()
# Out:
#                                                                                   001.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              0.000000
# ENSG00000284513 AC006063.2        0                                              0.000000
# ENSG00000284523 AC004834.1        0                                             11.335838
# ENSG00000284526 AC015802.6        0                                             22.671675
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   90.686700
#
#                                                                                     006.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              61.633252
# ENSG00000284513 AC006063.2        0                                               7.111529
# ENSG00000284523 AC004834.1        0                                              47.410194
# ENSG00000284526 AC015802.6        0                                              49.780703
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   182.529245
#
#                                                                                     016.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              35.140823
# ENSG00000284513 AC006063.2        0                                               4.685443
# ENSG00000284523 AC004834.1        0                                              39.826266
# ENSG00000284526 AC015802.6        0                                              77.309810
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   168.675948
#
#                                                                                   017.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              0.000000
# ENSG00000284513 AC006063.2        0                                              8.037403
# ENSG00000284523 AC004834.1        0                                             10.046754
# ENSG00000284526 AC015802.6        0                                             38.177666
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   31.144938
#
#                                                                                    018.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              0.000000
# ENSG00000284513 AC006063.2        0                                              2.417535
# ENSG00000284523 AC004834.1        0                                             21.757813
# ENSG00000284526 AC015802.6        0                                             80.987417
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   71.317277
#
#                                                                                 ...  \
# ensembl_id      ensembl_gene_name description                                   ...
# ENSG00000284512 AC092718.8        0                                             ...
# ENSG00000284513 AC006063.2        0                                             ...
# ENSG00000284523 AC004834.1        0                                             ...
# ENSG00000284526 AC015802.6        0                                             ...
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   ...
#
#                                                                                   242.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              0.000000
# ENSG00000284513 AC006063.2        0                                             16.066230
# ENSG00000284523 AC004834.1        0                                              0.000000
# ENSG00000284526 AC015802.6        0                                             21.178212
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   39.435292
#
#                                                                                    244.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              0.000000
# ENSG00000284513 AC006063.2        0                                             37.212558
# ENSG00000284523 AC004834.1        0                                              0.000000
# ENSG00000284526 AC015802.6        0                                              1.583513
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   94.219031
#
#                                                                                     255.VM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                              20.001871
# ENSG00000284513 AC006063.2        0                                              24.212791
# ENSG00000284523 AC004834.1        0                                              33.687361
# ENSG00000284526 AC015802.6        0                                              63.163802
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   100.009353
#
#                                                                                    256.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                             11.851566
# ENSG00000284513 AC006063.2        0                                             15.337321
# ENSG00000284523 AC004834.1        0                                             11.154415
# ENSG00000284526 AC015802.6        0                                             57.863530
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   94.115381
#
#                                                                                    261.CM
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                             12.194034
# ENSG00000284513 AC006063.2        0                                              3.251743
# ENSG00000284523 AC004834.1        0                                             21.136326
# ENSG00000284526 AC015802.6        0                                             19.510455
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   51.214945
#
# [5 rows x 37 columns]

# %% [markdown]
# First finding, ahead of proper quality checks:

# %%
tbm_vm_data.duplicated().any()
# Out:
# True

# %%
sum(tbm_vm_data.duplicated(keep=False))
# Out:
# 39

# %% [markdown]
# 39 genes have identical values across all patients, thus are correlated in 100%. Here are a few examples:

# %%
tbm_vm_data[tbm_vm_data.duplicated(keep=False)].head()
# Out:
#                                                                            001.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                      34.007513
# ENSG00000182776 AC239585.1        0                                      34.007513
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene    0.000000
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene    0.000000
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                 0.000000
#
#                                                                             006.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                      23.705097
# ENSG00000182776 AC239585.1        0                                      23.705097
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene   14.223058
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   14.223058
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                14.223058
#
#                                                                             016.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                      46.854430
# ENSG00000182776 AC239585.1        0                                      46.854430
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene    2.342722
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene    2.342722
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                 2.342722
#
#                                                                            017.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                       0.000000
# ENSG00000182776 AC239585.1        0                                       0.000000
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene   19.088833
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   19.088833
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                19.088833
#
#                                                                             018.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                      21.757813
# ENSG00000182776 AC239585.1        0                                      21.757813
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene    3.626302
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene    3.626302
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                 3.626302
#
#                                                                          ...  \
# ensembl_id      ensembl_gene_name description                            ...
# ENSG00000179028 AC245177.1        0                                      ...
# ENSG00000182776 AC239585.1        0                                      ...
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene   ...
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   ...
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                ...
#
#                                                                            242.TMD  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                      10.954248
# ENSG00000182776 AC239585.1        0                                      10.954248
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene   11.684531
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   11.684531
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                11.684531
#
#                                                                             244.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                       0.000000
# ENSG00000182776 AC239585.1        0                                       0.000000
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene    0.000000
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   33.253775
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                 0.000000
#
#                                                                             255.VM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                       8.421840
# ENSG00000182776 AC239585.1        0                                       8.421840
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene    0.000000
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   21.054601
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                 0.000000
#
#                                                                             256.CM  \
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                       4.880057
# ENSG00000182776 AC239585.1        0                                       4.880057
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene   11.154415
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene   11.154415
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                11.154415
#
#                                                                             261.CM
# ensembl_id      ensembl_gene_name description
# ENSG00000179028 AC245177.1        0                                      13.006970
# ENSG00000182776 AC239585.1        0                                      13.006970
# ENSG00000206588 RNU1-28P          RNA, U1 small nuclear 28, pseudogene   21.949262
# ENSG00000206596 RNU1-27P          RNA, U1 small nuclear 27, pseudogene    0.000000
# ENSG00000206652 RNU1-1            RNA, U1 small nuclear 1                21.949262
#
# [5 rows x 37 columns]

# %% [markdown]
# There are 12 groups of such genes and these are:

# %%
from helpers.data_frame import extract_duplicates

data_duplicates = extract_duplicates(tbm_vm_data.reset_index(), patient_columns, rna_index)
full_table(data_duplicates)
# Out:
#                                                  description  \
# group index
# 0     1      RNA, U1 small nuclear 28, pseudogene
#       2      RNA, U1 small nuclear 1
#       3      RNA, variant U1 small nuclear 18
#       4      RNA, U1 small nuclear 3
#       5      U1 spliceosomal RNA
# 1     6      RNA, U1 small nuclear 27, pseudogene
#       7      RNA, U1 small nuclear 2
#       8      RNA, U1 small nuclear 4
#       9      U1 spliceosomal RNA
# 2     10     activating transcription factor 4 pseudogene 1
#       11     activating transcription factor 4 pseudogene 2
# 3     12     0
#       13     0
# 4     14     C4B antisense RNA 1
#       15     C4A antisense RNA 1
# 5     16     family with sequence similarity 231 member A
#       17     family with sequence similarity 231 member C
# 6     18     0
#       19     0
#       20     0
# 7     21     chromosome X open reading frame 49B
#       22     chromosome X open reading frame 49
# 8     23     0
#       24     0
# 9     25     microRNA 3648-2
#       26     microRNA 3648-1
# 10    27     RNA, 5.8S ribosomal N3
#       28     RNA, 5.8S ribosomal N2
#       29     RNA, 5.8S ribosomal N4
#       30     RNA, 5.8S ribosomal 5
#       31     RNA, 5.8S ribosomal N1
#       32     RNA, 5.8S ribosomal N5
#       33     RNA, 5.8S ribosomal 4
#       34     RNA, 5.8S ribosomal 4
# 11    35     0
#       36     0
# 12    37     0
#       38     0
#       39     0
#
#             ensembl_gene_name       ensembl_id
# group index
# 0     1      RNU1-28P          ENSG00000206588
#       2      RNU1-1            ENSG00000206652
#       3      RNVU1-18          ENSG00000206737
#       4      RNU1-3            ENSG00000207513
#       5      U1                ENSG00000275405
# 1     6      RNU1-27P          ENSG00000206596
#       7      RNU1-2            ENSG00000207005
#       8      RNU1-4            ENSG00000207389
#       9      U1                ENSG00000273768
# 2     10     ATF4P1            ENSG00000213338
#       11     ATF4P2            ENSG00000273041
# 3     12     AL390038.1        ENSG00000224698
#       13     AL359258.1        ENSG00000238122
# 4     14     C4B-AS1           ENSG00000229776
#       15     C4A-AS1           ENSG00000233627
# 5     16     FAM231A           ENSG00000237847
#       17     FAM231C           ENSG00000279132
# 6     18     FP236315.2        ENSG00000279186
#       19     CU634019.3        ENSG00000279303
#       20     FP671120.2        ENSG00000279967
# 7     21     CXorf49B          ENSG00000215113
#       22     CXorf49           ENSG00000215115
# 8     23     AC245177.1        ENSG00000179028
#       24     AC239585.1        ENSG00000182776
# 9     25     MIR3648-2         ENSG00000264462
#       26     MIR3648-1         ENSG00000275708
# 10    27     RNA5-8SN3         ENSG00000273730
#       28     RNA5-8SN2         ENSG00000274917
#       29     RNA5-8SN4         ENSG00000275215
#       30     RNA5-8S5          ENSG00000275757
#       31     RNA5-8SN1         ENSG00000276700
#       32     RNA5-8SN5         ENSG00000277739
#       33     RNA5-8S4          ENSG00000278189
#       34     RNA5-8S4          ENSG00000278233
# 11    35     FP671120.1        ENSG00000278996
#       36     FP236383.1        ENSG00000280441
# 12    37     FP236383.2        ENSG00000280614
#       38     FP671120.3        ENSG00000280800
#       39     FP236383.3        ENSG00000281181

# %% [markdown]
# As the duplicated groups present genes having similar functions this appears to be a genuine artifact from the mapping procedure.
#
# Interestingly, there are many pseudogenes and RNA genes. I will keep the full data for now and remove the duplicates later on.
#
# Just to have it quickly accessible:

# %%
data_duplicates.to_csv(duplicates_path)

# %% [markdown]
# #### Differentially Expressed Genes (DEGs)

# %%
tbm_vm_deg.sort_values('padj').head()
# Out:
#                                                                              baseMean  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100336 APOL4             apolipoprotein L4                         80.607489
# ENSG00000125538 IL1B              interleukin 1 beta                       926.175471
# ENSG00000179388 EGR3              early growth response 3                  334.404894
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B   222.402492
# ENSG00000127946 HIP1              huntingtin interacting protein 1         249.836938
#
#                                                                            log2FoldChange  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100336 APOL4             apolipoprotein L4                              2.529792
# ENSG00000125538 IL1B              interleukin 1 beta                             4.576987
# ENSG00000179388 EGR3              early growth response 3                        3.485038
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B         2.320539
# ENSG00000127946 HIP1              huntingtin interacting protein 1               1.642896
#
#                                                                               lfcSE  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100336 APOL4             apolipoprotein L4                        0.479032
# ENSG00000125538 IL1B              interleukin 1 beta                       0.899595
# ENSG00000179388 EGR3              early growth response 3                  0.689505
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B   0.475704
# ENSG00000127946 HIP1              huntingtin interacting protein 1         0.354008
#
#                                                                                stat  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100336 APOL4             apolipoprotein L4                        5.281050
# ENSG00000125538 IL1B              interleukin 1 beta                       5.087830
# ENSG00000179388 EGR3              early growth response 3                  5.054402
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B   4.878117
# ENSG00000127946 HIP1              huntingtin interacting protein 1         4.640850
#
#                                                                                  pvalue  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100336 APOL4             apolipoprotein L4                        1.284456e-07
# ENSG00000125538 IL1B              interleukin 1 beta                       3.621846e-07
# ENSG00000179388 EGR3              early growth response 3                  4.317408e-07
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B   1.071032e-06
# ENSG00000127946 HIP1              huntingtin interacting protein 1         3.469786e-06
#
#                                                                                padj
# ensembl_id      ensembl_gene_name description
# ENSG00000100336 APOL4             apolipoprotein L4                        0.000941
# ENSG00000125538 IL1B              interleukin 1 beta                       0.001054
# ENSG00000179388 EGR3              early growth response 3                  0.001054
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B   0.001961
# ENSG00000127946 HIP1              huntingtin interacting protein 1         0.005083

# %%
tbm_vm_deg.tail()
# Out:
#                                                                                  baseMean  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                             15.697566
# ENSG00000284513 AC006063.2        0                                             13.256127
# ENSG00000284523 AC004834.1        0                                             27.773974
# ENSG00000284526 AC015802.6        0                                             54.314726
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   76.657661
#
#                                                                                 log2FoldChange  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                                  -0.284500
# ENSG00000284513 AC006063.2        0                                                   0.088160
# ENSG00000284523 AC004834.1        0                                                   0.674403
# ENSG00000284526 AC015802.6        0                                                   0.686323
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226         0.307070
#
#                                                                                    lfcSE  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                             0.810605
# ENSG00000284513 AC006063.2        0                                             0.892035
# ENSG00000284523 AC004834.1        0                                             0.791553
# ENSG00000284526 AC015802.6        0                                             0.585895
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   0.510789
#
#                                                                                     stat  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                            -0.350972
# ENSG00000284513 AC006063.2        0                                             0.098830
# ENSG00000284523 AC004834.1        0                                             0.852000
# ENSG00000284526 AC015802.6        0                                             1.171409
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   0.601167
#
#                                                                                   pvalue  \
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                             0.725609
# ENSG00000284513 AC006063.2        0                                             0.921274
# ENSG00000284523 AC004834.1        0                                             0.394214
# ENSG00000284526 AC015802.6        0                                             0.241434
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   0.547729
#
#                                                                                     padj
# ensembl_id      ensembl_gene_name description
# ENSG00000284512 AC092718.8        0                                                  NaN
# ENSG00000284513 AC006063.2        0                                                  NaN
# ENSG00000284523 AC004834.1        0                                                  NaN
# ENSG00000284526 AC015802.6        0                                                  NaN
# ENSG00000284543 LINC01226         long intergenic non-protein coding RNA 1226   0.829314

# %% [markdown]
# ##### Are there any duplicates?

# %%
tbm_vm_deg.duplicated().any()
# Out:
# True

# %% [markdown]
# This was expected as there are dupllicates in the data. Are those the same?

# %%
tv_deg_duplicates = extract_duplicates(tbm_vm_deg.reset_index(), deg_columns, rna_index)
set(tv_deg_duplicates.ensembl_id) == set(data_duplicates.ensembl_id)
# Out:
# True

# %% [markdown]
# ##### Can I quickly reproduce the log2FoldChange in Python?

# %%
from helpers.data_frame import select_columns

# %%
tmd = select_columns(tbm_vm_data, '.*TMD').T
vir = select_columns(tbm_vm_data, '.*VM').T

# %%
from numpy import log2

def log2_fold_change(a, b):
    fold_change = a.mean() / b.mean()
    return log2(fold_change)

# %%
DataFrame({'python': log2_fold_change(tmd, vir), 'deseq2': tbm_vm_deg['log2FoldChange']}).corr()   # Pearson ρ
# Out:
#           python    deseq2
# python  1.000000  0.986152
# deseq2  0.986152  1.000000

# %% [markdown]
# Good enough. The small differences may arise from the differences in DESeq2 procedure as explained by the author at [bioconductor forum](https://support.bioconductor.org/p/88813/).

# %%
tbm_vm_deg.to_csv(definite_tbm_vm_deg_path)

# %% [markdown]
# ### Definite TBM vs cryptococal (DEG_P75_TBM_CM)

# %%
tbm_cm = definite_tbm_rna['DEG_P75_TBM_CM']
tbm_cm.head()
# Out:
#         Ensembl_ID Feature                                      Description  \
# 0  ENSG00000100226  GTPBP1                           GTP binding protein 1
# 1  ENSG00000165997   ARL5B          ADP ribosylation factor like GTPase 5B
# 2  ENSG00000164691   TAGAP  T-cell activation RhoGTPase activating protein
# 3  ENSG00000108771   DHX58                            DExH-box helicase 58
# 4  ENSG00000128016   ZFP36                       ZFP36 ring finger protein
#
#       baseMean  log2FoldChange  ...      154.VM      156.VM      165.VM  \
# 0   580.453924        1.192190  ...  324.472455  422.875238  361.979002
# 1   222.402492        1.963330  ...   92.878733   91.957987   52.008477
# 2  1023.319959        1.964425  ...  272.605111  423.485786  170.587805
# 3   125.298558        1.785542  ...   41.011388   80.357567   53.048647
# 4  2070.881325        1.683438  ...  539.179135  827.809745  778.046820
#
#         255.VM      205.VM
# 0   464.253944  512.930995
# 1   147.382204   38.469825
# 2   392.668301  621.928831
# 3   225.284227   76.939649
# 4  1328.545299  925.680155
#
# [5 rows x 47 columns]

# %%
tbm_cm.tail()
# Out:
#             Ensembl_ID     Feature  \
# 21483  ENSG00000179041        RRS1
# 21484  ENSG00000188582       PAQR9
# 21485  ENSG00000092470       WDR76
# 21486  ENSG00000243508  AC108688.1
# 21487  ENSG00000160973       FOXH1
#
#                                           Description   baseMean  \
# 21483          ribosome biogenesis regulator homolog   54.538767
# 21484  progestin and adipoQ receptor family member 9   21.484805
# 21485                            WD repeat domain 76   50.967584
# 21486                                               0  12.289421
# 21487                                forkhead box H1   29.928712
#
#        log2FoldChange  ...      154.VM     156.VM     165.VM     255.VM  \
# 21483        0.000362  ...  110.971992  42.315703  98.816107  50.531041
# 21484       -0.000857  ...   18.093260  13.572961  28.084578  33.687361
# 21485        0.000159  ...   80.816559  47.904569  74.892207  47.372851
# 21486        0.000205  ...   14.474608  11.130768  26.004239   9.474570
# 21487       -0.000015  ...   16.887042  28.601846  43.687121  18.949141
#
#           205.VM
# 21483  69.726557
# 21484  45.682917
# 21485  56.903282
# 21486  15.227639
# 21487   6.411637
#
# [5 rows x 47 columns]

# %%
assert (tbm_cm['Feature'] == tbm_cm['Feature.1']).all()

# %%
tbm_cm = tbm_cm.drop('Feature.1', axis='columns')
tbm_cm = tbm_cm.rename(columns={'Feature': 'ensembl_gene_name'})
tbm_cm['Description'] = tbm_cm['Description'].replace('0', nan)

# %%
tbm_cm.columns = to_lowercase(tbm_cm.columns, limit_to=rna_raw_index)

# %%
patient_columns = list(tbm_cm.columns.difference(deg_columns + rna_index))

tbm_cm_deg = tbm_cm[rna_index + deg_columns].set_index(rna_index)
tbm_cm_data = tbm_cm[rna_index + patient_columns].set_index(rna_index)

# %% [markdown]
# #### Data

# %% [markdown]
# So far the data looks similar, including the number of columns. What are the differences?

# %%
set(tbm_vm_data.columns) == set(tbm_cm_data.columns)
# Out:
# True

# %% [markdown]
# The column names are the same

# %%
(tbm_cm_data[tbm_cm_data.columns] == tbm_cm_data).all().all()
# Out:
# True

# %% [markdown]
# And values are also the same. So the data is just duplicated across the spread sheets.

# %% [markdown]
# As there are no measurments in the third spreadsheet I will just save the data now:

# %%
rna_data_definite_tbm = tbm_cm_data = tbm_cm_data

# %%
rna_data_definite_tbm.to_csv(tbm_subset_clean_path)

# %% [markdown]
# ### DEGs

# %%
tbm_cm_deg.sort_values('padj').head()
# Out:
#                                                                                       baseMean  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100226 GTPBP1            GTP binding protein 1                             580.453924
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B            222.402492
# ENSG00000164691 TAGAP             T-cell activation RhoGTPase activating protein   1023.319959
# ENSG00000108771 DHX58             DExH-box helicase 58                              125.298558
# ENSG00000128016 ZFP36             ZFP36 ring finger protein                        2070.881325
#
#                                                                                    log2FoldChange  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100226 GTPBP1            GTP binding protein 1                                  1.192190
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B                 1.963330
# ENSG00000164691 TAGAP             T-cell activation RhoGTPase activating protein         1.964425
# ENSG00000108771 DHX58             DExH-box helicase 58                                   1.785542
# ENSG00000128016 ZFP36             ZFP36 ring finger protein                              1.683438
#
#                                                                                       lfcSE  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100226 GTPBP1            GTP binding protein 1                            0.219708
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B           0.393233
# ENSG00000164691 TAGAP             T-cell activation RhoGTPase activating protein   0.394441
# ENSG00000108771 DHX58             DExH-box helicase 58                             0.367150
# ENSG00000128016 ZFP36             ZFP36 ring finger protein                        0.348691
#
#                                                                                        stat  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100226 GTPBP1            GTP binding protein 1                            5.426243
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B           4.992789
# ENSG00000164691 TAGAP             T-cell activation RhoGTPase activating protein   4.980279
# ENSG00000108771 DHX58             DExH-box helicase 58                             4.863249
# ENSG00000128016 ZFP36             ZFP36 ring finger protein                        4.827880
#
#                                                                                          pvalue  \
# ensembl_id      ensembl_gene_name description
# ENSG00000100226 GTPBP1            GTP binding protein 1                            5.755269e-08
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B           5.951353e-07
# ENSG00000164691 TAGAP             T-cell activation RhoGTPase activating protein   6.349261e-07
# ENSG00000108771 DHX58             DExH-box helicase 58                             1.154747e-06
# ENSG00000128016 ZFP36             ZFP36 ring finger protein                        1.379940e-06
#
#                                                                                        padj
# ensembl_id      ensembl_gene_name description
# ENSG00000100226 GTPBP1            GTP binding protein 1                            0.000517
# ENSG00000165997 ARL5B             ADP ribosylation factor like GTPase 5B           0.001903
# ENSG00000164691 TAGAP             T-cell activation RhoGTPase activating protein   0.001903
# ENSG00000108771 DHX58             DExH-box helicase 58                             0.002481
# ENSG00000128016 ZFP36             ZFP36 ring finger protein                        0.002481

# %% [markdown]
# ##### Duplicates
# Again, are the same as the data duplicates?

# %%
tbm_cm_duplicates = extract_duplicates(tbm_cm_deg.reset_index(), deg_columns, rna_index)
tbm_cm_duplicates.head()
# Out:
#                                                  description  \
# group index
# 0     1      activating transcription factor 4 pseudogene 1
#       2      activating transcription factor 4 pseudogene 2
# 1     3                 chromosome X open reading frame 49B
#       4                  chromosome X open reading frame 49
# 2     5        family with sequence similarity 231 member A
#
#             ensembl_gene_name       ensembl_id
# group index
# 0     1                ATF4P1  ENSG00000213338
#       2                ATF4P2  ENSG00000273041
# 1     3              CXorf49B  ENSG00000215113
#       4               CXorf49  ENSG00000215115
# 2     5               FAM231A  ENSG00000237847

# %%
set(data_duplicates.ensembl_id) == set(tbm_cm_duplicates.ensembl_id)
# Out:
# True

# %% [markdown]
# ##### Quick log2FoldChange check

# %%
cm = select_columns(tbm_cm_data, '.*CM').T
DataFrame({'python': log2_fold_change(tmd, cm), 'deseq2': tbm_cm_deg['log2FoldChange']}).corr()   # Pearson ρ
# Out:
#           python    deseq2
# python  1.000000  0.985204
# deseq2  0.985204  1.000000

# %% [markdown]
# Everything is fine here!

# %%
tbm_cm_deg.to_csv(definite_tbm_cm_deg_path)

# %% [markdown]
# ### Cryptococcal vs viral (DEG_P75_CM_VM)

# %% [markdown]
# So this time there are no data, only DEGs:

# %%
cm_vm = definite_tbm_rna['DEG_P75_CM_VM']
cm_vm
# Out:
#             Ensembl_ID     Feature  \
# 0      ENSG00000147457       CHMP7
# 1      ENSG00000136872       ALDOB
# 2      ENSG00000164300     SERINC5
# 3      ENSG00000178075     GRAMD1C
# 4      ENSG00000179388        EGR3
# ...                ...         ...
# 21483  ENSG00000272588  AC139887.4
# 21484  ENSG00000085117        CD82
# 21485  ENSG00000102309        PIN4
# 21486  ENSG00000188305       PEAK3
# 21487  ENSG00000233382      NKAPP1
#
#                                              Description    baseMean  \
# 0                 charged multivesicular body protein 7   146.620981
# 1                     aldolase, fructose-bisphosphate B     8.163739
# 2                                 serine incorporator 5   209.646143
# 3                             GRAM domain containing 1C    33.411785
# 4                               early growth response 3   334.404894
# ...                                                  ...         ...
# 21483                                                  0   16.588560
# 21484                                     CD82 molecule   156.867101
# 21485  peptidylprolyl cis/trans isomerase, NIMA-inter...   31.521707
# 21486                              PEAK family member 3    81.830585
# 21487              NFKB activating protein pseudogene 1    21.802386
#
#        log2FoldChange     lfcSE      stat    pvalue      padj
# 0           -0.950047  0.215228 -4.414134  0.000010  0.217920
# 1            3.487265  0.897156  3.887021  0.000101  0.432580
# 2           -1.151876  0.286659 -4.018282  0.000059  0.432580
# 3            1.825325  0.474786  3.844523  0.000121  0.432580
# 4            2.543094  0.647976  3.924671  0.000087  0.432580
# ...               ...       ...       ...       ...       ...
# 21483        0.000253  0.706493  0.000359  0.999714  0.999917
# 21484        0.000042  0.486934  0.000086  0.999932  0.999997
# 21485       -0.000020  0.509869 -0.000039  0.999969  0.999997
# 21486        0.000002  0.501223  0.000004  0.999997  0.999997
# 21487        0.000005  0.679600  0.000007  0.999994  0.999997
#
# [21488 rows x 9 columns]

# %% [markdown]
# #### DEGs

# %%
cm_vm['Description'] = cm_vm['Description'].replace('0', nan)
cm_vm = cm_vm.rename(columns={'Feature': 'ensembl_gene_name'})
cm_vm.columns = to_lowercase(cm_vm.columns, limit_to=rna_raw_index)
cm_vm = cm_vm.set_index(rna_index)

# %% [markdown]
# ##### Duplicates

# %%
cm_vm_duplicates = extract_duplicates(cm_vm.reset_index(), deg_columns, rna_index)
set(cm_vm_duplicates.ensembl_id) == set(tbm_cm_duplicates.ensembl_id)
# Out:
# True

# %% [markdown]
# ##### Quick log2FoldChange check

# %%
DataFrame({'python': log2_fold_change(cm, vir), 'deseq2': cm_vm['log2FoldChange']}).corr()   # Pearson ρ
# Out:
#           python    deseq2
# python  1.000000  0.995362
# deseq2  0.995362  1.000000

# %% [markdown]
# Great!

# %%
cm_vm.to_csv(cm_vm_deg_path)

# %% [markdown]
# ## All Samples

# %%
rna_seq = read_table(all_samples_path)

# %%
rna_seq
# Out:
#             Ensembl_ID      Feature     001.TMD      006.CM     012.BM  ...  \
# 0      ENSG00000000003       TSPAN6   11.596119    7.806308   1.391555  ...
# 1      ENSG00000000005         TNMD    0.000000    0.000000   0.000000  ...
# 2      ENSG00000000419         DPM1    0.000000   31.225230  36.876198  ...
# 3      ENSG00000000457        SCYL3  127.557308  145.717740  86.276387  ...
# 4      ENSG00000000460     C1orf112   46.384476    0.000000  50.791744  ...
# ...                ...          ...         ...         ...        ...  ...
# 38659  ENSG00000284543    LINC01226   92.768952  200.361893  27.135315  ...
# 38660  ENSG00000284546      SSU72P3    0.000000    0.000000   0.000000  ...
# 38661  ENSG00000284552  AC106774.10    0.000000    0.000000   0.000000  ...
# 38662  ENSG00000284572  AC099654.15    0.000000   28.623128   0.000000  ...
# 38663  ENSG00000284600   AC093390.2   11.596119   23.418923   4.174664  ...
#
#            174.CM     011.TMR     043.TMS      078.CM      261.CM
# 0        4.431071   51.810470   35.628629    0.000000   20.705553
# 1        0.000000   11.102244    0.000000    0.000000    4.141111
# 2       25.478656   11.102244    0.000000  161.520987   39.754662
# 3      121.854440   96.219444    3.958737   92.395480  125.889763
# 4       33.233029   49.960096   38.267787    0.000000   30.644219
# ...           ...         ...         ...         ...         ...
# 38659  175.027287  170.234402  318.018506  131.406905   52.177994
# 38660    0.000000   14.802991    0.000000    0.000000    0.000000
# 38661   11.077676    9.251870    0.000000   27.376439    0.828222
# 38662    0.000000    1.850374    0.000000    0.000000    0.000000
# 38663   17.724282   11.102244    0.000000    0.000000    8.282221
#
# [38664 rows x 51 columns]

# %% [markdown]
# Note to self: this is on the gene level. Are there transcript-level data available?

# %%
assert not rna_seq.duplicated().any()

# %%
rna_seq = rna_seq.rename(columns={'Feature': 'ensembl_gene_id'})
rna_seq_index = ['Ensembl_ID', 'ensembl_gene_id']
rna_seq.columns = to_lowercase(rna_seq.columns, limit_to=rna_seq_index)
rna_seq_index = to_lowercase(rna_seq_index)

# %%
rna_seq = rna_seq.set_index(rna_seq_index)

# %%
rna_seq.duplicated().any()
# Out:
# True

# %%
rna_duplicates= extract_duplicates(rna_seq.reset_index(), list(rna_seq.columns.difference(rna_seq_index)), rna_seq_index)
rna_duplicates
# Out:
#             ensembl_gene_id       ensembl_id
# group index
# 0     1          AC009238.1  ENSG00000227120
#       2          AC009237.6  ENSG00000235959
# 1     3          AC141586.2  ENSG00000260176
#       4          AC093525.5  ENSG00000261288
# 2     5          AC008175.1  ENSG00000235059
# ...                     ...              ...
# 31    76         FP671120.1  ENSG00000278996
#       77         FP236383.1  ENSG00000280441
# 32    78         FP236383.2  ENSG00000280614
#       79         FP671120.3  ENSG00000280800
#       80         FP236383.3  ENSG00000281181
#
# [80 rows x 2 columns]

# %% [markdown]
# More duplicates - likely due to having more genes.

# %%
rna_duplicates.to_csv(all_samples_duplicates_path)

# %%
rna_seq.to_csv(all_samples_clean_path)

# %% [markdown]
# ### Additional patients
#
# should be tbm but not definite:

# %%
set(rna_seq.columns) - set(rna_data_definite_tbm.columns)
# Out:
# {'011.TMR',
#  '012.BM',
#  '028.TMR',
#  '043.TMS',
#  '056.TMS',
#  '079.TMR',
#  '100.TMS',
#  '155.TMR',
#  '169.TMR',
#  '172.TMR',
#  '234.BM',
#  '239.TMS'}

# %% [markdown]
# R - probable, S - possible, BM - bacterial (non-TB or TB even less likely than in the "possible" group)

# %% [markdown]
# ### Additional genes

# %% [markdown]
# 38664 genes, much more than for the definite subset (21488). Is it due to the completeness filtering?

# %%
ratio_empty = ((rna_seq == 0).apply(sum, axis=1) / len(rna_seq.columns))

# %%
len(rna_seq.loc[~(ratio_empty > 0.25)])
# Out:
# 20688

# %% [markdown]
# Almost. I got fewer genes: 20688, not 21488. Maybe it was 1/5 and not 1/4?

# %%
len(rna_seq.loc[~(ratio_empty > 0.20)])
# Out:
# 18424

# %% [markdown]
# Or maybe the filtering criterion was applied after taking the subset of the data - that would make sense...

# %%
subset = rna_seq[rna_data_definite_tbm.columns]
ratio_empty_subset = ((subset == 0).apply(sum, axis=1) / len(subset.columns))
filtered = subset[ratio_empty_subset <= 0.25]
len(filtered)
# Out:
# 21511

# %% [markdown]
# Now it is a little bit more. Close enough?

# %%
len(filtered) - len(rna_data_definite_tbm)
# Out:
# 23

# %% [markdown]
# So what is the difference?

# %%
reproduction = set(filtered.reset_index().ensembl_id)
original_genes = set(rna_data_definite_tbm.reset_index().ensembl_id)
original_genes - reproduction
# Out:
# set()

# %% [markdown]
# I got some additional genes:

# %%
difference = Series(list(reproduction - original_genes))

# %%
ratio_empty_subset.loc[difference].to_frame().T
# Out:
# ensembl_id      ENSG00000141748 ENSG00000156574 ENSG00000177553  \
# ensembl_gene_id           ARL5C           NODAL      AL953897.1
# 0                      0.243243        0.243243        0.243243
#
# ensembl_id      ENSG00000189253 ENSG00000197744  ... ENSG00000259856  \
# ensembl_gene_id         TRIM64B          PTMAP2  ...         RAB43P1
# 0                      0.243243        0.243243  ...        0.243243
#
# ensembl_id      ENSG00000271361 ENSG00000279730 ENSG00000283093  \
# ensembl_gene_id       HTATSF1P2         SETD8P1         CENPVL2
# 0                      0.243243        0.243243        0.243243
#
# ensembl_id      ENSG00000284294
# ensembl_gene_id      AC007326.5
# 0                      0.243243
#
# [1 rows x 23 columns]

# %% [markdown]
# Okay, it is close enough. Maybe R or Excel does some funny rounding errors and thus the 23 were excluded too. Or maybe a different set of samples was excluded initially?
#
# Also, it is barely 0.1% of the data:

# %%
f'{23 / 21511 * 100:.2f}%'
# Out:
# '0.11%'

# %% [markdown]
# ### Metadata

# %%
metadata = read_table(metadata_path, index_col=0)

# %%
metadata
# Out:
#         Condition Group Batch
# 001.TMD       TMD   TBM   FC2
# 006.CM         CM    CM   FC2
# 012.BM         BM    BM   FC2
# 016.CM         CM    CM   FC2
# 017.TMD       TMD   TBM   FC2
# ...           ...   ...   ...
# 174.CM         CM    CM   FC1
# 011.TMR       TMR   TBM   FC1
# 043.TMS       TMS   TMS   FC1
# 078.CM         CM    CM   FC1
# 261.CM         CM    CM   FC1
#
# [49 rows x 3 columns]

# %%
metadata.Batch.unique()
# Out:
# array(['FC2', 'FC1'], dtype=object)

# %% [markdown]
# Are al samples present?

# %%
assert set(rna_seq.columns) == set(metadata.index)

# %% [markdown]
# Are ids, conditions, and groups matching?

# %%
from_id = metadata.index.str.split('.').str[1]
assert (from_id == metadata.Condition).all()

# %% [markdown]
# What I expected:

# %%
condition_to_group = {
    'TMD': 'TBM',
    'CM': 'CM',
    'TMR': 'TBM',
    'TMS': 'TBM',
    'BM': 'BM',
    'VM': 'VM'
}

# %%
mapped = from_id.map(condition_to_group.get)

# %%
(mapped == metadata.Group).all()
# Out:
# False

# %% [markdown]
# It seems that the "probable TB" condition stands on its own.

# %%
metadata[~(mapped == metadata.Group)]
# Out:
#         Condition Group Batch
# 056.TMS       TMS   TMS   FC2
# 100.TMS       TMS   TMS   FC2
# 239.TMS       TMS   TMS   FC1
# 043.TMS       TMS   TMS   FC1

# %% [markdown]
# But is this really relevant? Is this used anywhere?
